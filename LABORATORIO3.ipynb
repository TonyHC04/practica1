# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyHC04/practica1/blob/main/LABORATORIO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/atenciones_abogadas_de_las_mujeres.csv"
df = pd.read_csv(path)
edad = df["usuaria_edad"]
dist = edad.value_counts()
plt.bar(dist.index, dist.values)
plt.xlim(0, 100)
plt.show()
# Out:
# <ipython-input-4-0f3f1dfa7fb1>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/atenciones_abogadas_de_las_mujeres.csv"
df = pd.read_csv(path)
conteo = df["usuaria_estado_civil"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-7-deb04e02ffe7>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujerees.csv"
df = pd.read_csv(path)
conteo = df["AÑO"].value_counts()
plt.ylim(2015, 2023)
plt.barh(conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-5-1177dbfdb1f8>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujerees - atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujerees (1).csv"
df = pd.read_csv(path)
df.info()
conteo = df["anio_mes"].value_counts()
plt.barh(conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-30-6e9262671575>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121995 entries, 0 to 121994
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fecha                       121995 non-null  object
#  1   agencia                     120918 non-null  object
#  2   usuaria_sexo                121591 non-null  object
#  3   usuaria_nacionalidad        121641 non-null  object
#  4   usuaria_ent_fed_nacimiento  119967 non-null  object
#  5   usuaria_estado_civil        88051 non-null   object
#  6   usuaria_edad                120005 non-null  float64
#  7   usuaria_hijas               108979 non-null  float64
#  8   usuaria_hijos               102770 non-null  float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/atenciones_abogadas_de_las_mujerees.csv"
df = pd.read_csv(path)
df_filtrado = df.query("usuaria_edad <= 160")
print(df_filtrado["usuaria_edad"])
plt.boxplot(df_filtrado["usuaria_edad"])
plt.show()
# Out:
# <ipython-input-2-bb4d55f8908d>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# 0         33.0
# 1         26.0
# 2         25.0
# 3         55.0
# 4         33.0
#           ...
# 121990    50.0
# 121991    31.0
# 121992    20.0
# 121993    26.0
# 121994    31.0
# Name: usuaria_edad, Length: 119978, dtype: float64
